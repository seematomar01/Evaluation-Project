# %%
# Import required libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df= pd.read_csv('https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv')

# %%
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
# print the shape of df
df.shape
# Out:
# (30, 17)

# %% [markdown]
# There are 30 rows and 17 columns in my dataset.

# %%
# Checking for null values
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
# ERA is a float type data and except ERA all columns are int type data.

# %%
#Checking for null values in heat map
plt.figure(figsize=[10,8])
sns.heatmap(df.isnull())
plt.title('Null Values')
plt.show()

# %%
#Checking description of dataset
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# min    13.000000  100.000000  375.000000   973.00000   44.000000  525.000000
# 25%    23.000000  140.250000  428.250000  1157.50000   69.000000  636.250000
# 50%    31.000000  158.500000  473.000000  1261.50000   83.500000  695.500000
# 75%    39.000000  177.000000  501.250000  1311.50000   96.500000  732.500000
# max    49.000000  232.000000  570.000000  1518.00000  134.000000  844.000000
#
#                ER        ERA         CG        SHO         SV           E
# count   30.000000  30.000000  30.000000  30.000000  30.000000   30.000000
# mean   635.833333   3.956333   3.466667  11.300000  43.066667   94.333333
# std     70.140786   0.454089   2.763473   4.120177   7.869335   13.958889
# min    478.000000   2.940000   0.000000   4.000000  28.000000   75.000000
# 25%    587.250000   3.682500   1.000000   9.000000  37.250000   86.000000
# 50%    644.500000   4.025000   3.000000  12.000000  42.000000   91.000000
# 75%    679.250000   4.220000   5.750000  13.000000  46.750000   96.750000
# max    799.000000   5.040000  11.000000  21.000000  62.000000  126.000000

# %%
#Checking value counts of target column
df['W'].value_counts()
# Out:
# 68     3
# 83     2
# 74     2
# 76     2
# 81     2
# 64     1
# 93     1
# 92     1
# 90     1
# 88     1
# 87     1
# 86     1
# 85     1
# 84     1
# 80     1
# 97     1
# 100    1
# 78     1
# 63     1
# 79     1
# 71     1
# 67     1
# 98     1
# 95     1
# Name: W, dtype: int64

# %% [markdown]
# As  we see our dataset is not having any null value so we can now move to the visualization part

# %%
import warnings 
warnings.filterwarnings('ignore')
plt.figure(figsize = (25,50), facecolor = 'white')
plotnumber = 1

for column in df:
    if plotnumber <=17:
        ax = plt.subplot(10,2,plotnumber)
        sns.distplot(df[column], color = 'skyblue')
        plt.xlabel(column,fontsize=20)
        
    plotnumber +=1
plt.show()

# %% [markdown]
# Almost all the columns are normally distributed.Except R,SO,CG and E.

# %%
plt.figure(figsize = (25,50), facecolor = 'white')
plotnumber = 1

for column in df:
    if plotnumber <=17:
        ax = plt.subplot(10,2,plotnumber)
        sns.histplot(df[column], color = 'skyblue')
        plt.xlabel(column,fontsize=20)
        
    plotnumber += 1
plt.show()

# %%
plt.figure(figsize = (25,50), facecolor = 'white')
plotnumber = 1
for column in df:
    if plotnumber <=17:
        ax = plt.subplot(10,2,plotnumber)
        sns.boxplot(df[column], color = 'skyblue')
        plt.xlabel(column,fontsize=20)
        
    plotnumber +=1
plt.show()

# %% [markdown]
# As shown in boxplot R,ERA,SHO,SV and E input variable is having outliers in it. So,we need remove outliers from that the input variables.

# %%
#Check the relation between feature and variables
plt.figure(figsize = (25,20), facecolor = 'white')
plotnumber = 1

for column in df:
    if plotnumber <=20:
        plt.figure(figsize = (10,6))
        sns.regplot(df[column], df['W'])
        plt.title('Scatter Plot for Wins vs other attributes')
        plt.xlabel(column)
        plt.ylabel('W')
        
plt.tight_layout()

# %% [markdown]
# RA,ER,ERA have good relation with Win. Reset all the Columns does not good Relation with Win because data is scatter across all the places.

# %%
#Check for multicolinaeirty
plt.figure(figsize = [20, 15])
sns.heatmap(df.corr(), annot = True)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# In this chart it is showing that RA,ER,ERA columns are highly correlated with each other. We are dropping two columns(er,era) and keeping RA from them because these have same kind of effect on wins, will not affect the prediction model.

# %% [markdown]
# ##### Removing Outliers
# Zscore method

# %%
#Features having outliers
features=df[['R','ERA','SHO','SV','E']]

# %%
from scipy.stats import zscore
z=np.abs(zscore(features))
df_new=df[(z<3).all(axis=1)]
df_new.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
#Checking shape of new dataset
df_new.shape
# Out:
# (29, 17)

# %% [markdown]
# There are 29 rows and 17 columns of shape of new dataset after removing outliers.

# %%
#Checking dataloss
Dataloss = (((30-29)/30)*100)

# %%
Dataloss
# Out:
# 3.3333333333333335

# %% [markdown]
# So, I can see dataloss in zscore method after removing outliers of 3.33% which is less than 10%

# %% [markdown]
# ### Checking for Skewness:

# %%
#Checking for Skewness
df_new.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.783772
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG     0.854980
# SHO    0.526943
# SV     0.627480
# E      0.840271
# dtype: float64

# %% [markdown]
# I can see that there is skewness in Hits(H),Completed games(CG),Shoutouts(SHO),Saves(SV),Errors(E).

# %% [markdown]
# ### Removing Skewness

# %%
#list of skewed features
skew_features=["H","CG","SHO","SV","E"]

# %%
#Removing skewness in H using log1p
df_new["H"]=np.log1p(df_new["H"])

# %%
from sklearn.preprocessing import PowerTransformer
scaler = PowerTransformer(method='yeo-johnson')

# %%
#Removing skewness using yeo-johnson
df_new[['E','SHO','SV','CG']] = scaler.fit_transform(df_new[['E','SHO','SV','CG']].values)

# %%
#Checking skewness after removing skewness
df_new.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.738455
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG    -0.045947
# SHO    0.000529
# SV    -0.000925
# E      0.065585
# dtype: float64

# %%
#After removing let's check how the data has been distributed in each column of skew_features.

plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in df_new[skew_features]:
    if plotnumber<=9:
        ax = plt.subplot(3,3,plotnumber)
        sns.distplot(df_new[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %% [markdown]
# From the above plot we conclude that skewness is removed

# %% [markdown]
# #### Split data into x and y

# %%
x = df_new.drop("W",axis=1)
y = df_new["W"]

# %%
x.head()
# Out:
#      R    AB         H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  \
# 0  724  5575  7.311886  300  42  139  383   973  104  641  601  3.73
# 1  696  5467  7.207860  277  44  156  439  1264   70  700  653  4.07
# 2  669  5439  7.241366  303  29  141  533  1157   86  640  584  3.67
# 3  622  5533  7.231287  260  27  136  404  1231   68  701  643  3.98
# 4  689  5605  7.323831  289  49  151  455  1259   83  803  746  4.64
#
#          CG       SHO        SV         E
# 0 -0.307098 -0.787002  1.532753 -0.348265
# 1 -0.307098  0.236737  0.312020 -0.540820
# 2  2.011315 -0.252844 -0.664137 -1.326125
# 3  1.264463 -0.513555 -0.820689  0.650818
# 4  1.264463  0.236737 -1.149165 -0.540820

# %%
y.head()
# Out:
# 0    95
# 1    83
# 2    81
# 3    76
# 4    74
# Name: W, dtype: int64

# %%
#Importing necessary libraries
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
ssc=StandardScaler()
X = pd.DataFrame(ssc.fit_transform(x), columns=x.columns)

# %%
X.head()
# Out:
#           R        AB         H        2B        3B        HR        BB  \
# 0  0.959398  0.830084  1.723726  1.556538  1.010845 -0.765863 -1.536359
# 1  0.331147 -0.702831 -0.949846  0.201171  1.208917 -0.181389 -0.495021
# 2 -0.274666 -1.100253 -0.088700  1.733325 -0.276617 -0.697101  1.252941
# 3 -1.329231  0.233951 -0.347747 -0.800621 -0.474688 -0.869006 -1.145857
# 4  0.174084  1.255894  2.030708  0.908319  1.704094 -0.353293 -0.197495
#
#          SO        SB        RA        ER       ERA        CG       SHO  \
# 0 -2.727623  0.905953 -0.664514 -0.511148 -0.511388 -0.307098 -0.787002
# 1  0.121896 -0.585315  0.154638  0.232161  0.238952 -0.307098  0.236737
# 2 -0.925866  0.116458 -0.678397 -0.754153 -0.643801  2.011315 -0.252844
# 3 -0.201246 -0.673037  0.168522  0.089217  0.040333  1.264463 -0.513555
# 4  0.072935 -0.015124  1.584683  1.561540  1.496876  1.264463  0.236737
#
#          SV         E
# 0  1.532753 -0.348265
# 1  0.312020 -0.540820
# 2 -0.664137 -1.326125
# 3 -0.820689  0.650818
# 4 -1.149165 -0.540820

# %% [markdown]
# remove the columns that are mutlicolinear

# %%
#Droping ER
X = X.drop(["ER","ERA"],axis=1)

# %%
X.head()
# Out:
#           R        AB         H        2B        3B        HR        BB  \
# 0  0.959398  0.830084  1.723726  1.556538  1.010845 -0.765863 -1.536359
# 1  0.331147 -0.702831 -0.949846  0.201171  1.208917 -0.181389 -0.495021
# 2 -0.274666 -1.100253 -0.088700  1.733325 -0.276617 -0.697101  1.252941
# 3 -1.329231  0.233951 -0.347747 -0.800621 -0.474688 -0.869006 -1.145857
# 4  0.174084  1.255894  2.030708  0.908319  1.704094 -0.353293 -0.197495
#
#          SO        SB        RA        CG       SHO        SV         E
# 0 -2.727623  0.905953 -0.664514 -0.307098 -0.787002  1.532753 -0.348265
# 1  0.121896 -0.585315  0.154638 -0.307098  0.236737  0.312020 -0.540820
# 2 -0.925866  0.116458 -0.678397  2.011315 -0.252844 -0.664137 -1.326125
# 3 -0.201246 -0.673037  0.168522  1.264463 -0.513555 -0.820689  0.650818
# 4  0.072935 -0.015124  1.584683  1.264463  0.236737 -1.149165 -0.540820

# %%
X.shape
# Out:
# (29, 14)

# %% [markdown]
# Multicolinearity issue is solved.

# %% [markdown]
# ##### Divide data into train and test

# %%
 X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.22,random_state=99)

# %%
X_train.shape
# Out:
# (22, 14)

# %%
X_test.shape
# Out:
# (7, 14)

# %%
y_train.shape
# Out:
# (22,)

# %%
y_test.shape
# Out:
# (7,)

# %% [markdown]
# ## Model Building

# %%
#Importing necessary libraries
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import SGDRegressor 
from sklearn.metrics import classification_report
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import BaggingRegressor
from sklearn import metrics
from sklearn.metrics import mean_squared_error,mean_absolute_error, r2_score
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso,Ridge

# %% [markdown]
# ### 1)Linear Regression

# %%
LR=LinearRegression()
LR.fit(X_train,y_train)
print(LR.score(X_train,y_train))
LR_predict=LR.predict(X_test)
# Out:
# 0.9296510217185521

# %%
print('MSE:',mean_squared_error(LR_predict,y_test))
print('MAE:',mean_absolute_error(LR_predict,y_test))
print('r2_score:',r2_score(LR_predict,y_test))
print('rmse:',np.sqrt(mean_squared_error(y_test,LR_predict)))
# Out:
# MSE: 30.78333828507663
# MAE: 4.623018023471817
# r2_score: 0.6807647449466344
# rmse: 5.548273450820231

# %% [markdown]
# LR is giving me 68% r2_score.

# %% [markdown]
# ## 2)SGD

# %%
sgd=SGDRegressor()
sgd.fit(X_train,y_train)
pred=sgd.predict(X_test)
print('R2_score:',r2_score(y_test,pred))
print('mae:',mean_squared_error(y_test,pred))
print('mae:',mean_absolute_error(y_test,pred))
print('rmse:',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2_score: 0.7855091497415402
# mae: 29.100717806494718
# mae: 4.491658307311458
# rmse: 5.394508115342373

# %% [markdown]
# SGD is giving me 78% r2_score.

# %% [markdown]
# ## 3)Lasso Regressor

# %%
parameters={'alpha':[0.0001,0.001,0.01,0.1,1,10],'random_state':list(range(0,100))}
ls=Lasso()
Z=GridSearchCV(ls,parameters)
Z.fit(X_train,y_train)
print(Z.best_params_)
# Out:
# {'alpha': 1, 'random_state': 0}

# %%
ls=Lasso(alpha=1,random_state=0)
ls.fit(X_train,y_train)
pred=ls.predict(X_test)
print('R2_score:',r2_score(y_test,pred))
print('mse:',mean_squared_error(y_test,pred))
print('mae:',mean_absolute_error(y_test,pred))
print('rmse:',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2_score: 0.866150365554374
# mse: 18.15984428152086
# mae: 3.3880571291812283
# rmse: 4.261436879917484

# %% [markdown]
# Lasso is giving me 86%r2_score

# %% [markdown]
# ## 4)Ridge Regressor

# %%
parameters={'alpha':[0.001,0.01,0.1,1,10],'solver':['auto','svd','cholesky','lsqr','sparse_cg','sag','saga']}
rd=Ridge()
Z1=GridSearchCV(rd,parameters)
Z1.fit(X_train,y_train)
print(Z1.best_params_)
# Out:
# {'alpha': 10, 'solver': 'lsqr'}

# %%
rd=Ridge(alpha=10,solver='lsqr')
rd.fit(X_train,y_train)
pred=rd.predict(X_test)
print('R2_score:',r2_score(y_test,pred))
print('mse:',mean_squared_error(y_test,pred))
print('mae:',mean_absolute_error(y_test,pred))
print('rmse:',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2_score: 0.692394090062741
# mse: 41.73396100536526
# mae: 5.603772629212078
# rmse: 6.4601827377687435

# %% [markdown]
# Ridge is giving 69%r2_score.

# %% [markdown]
# ## 5) RandomForest

# %%
rf= RandomForestRegressor()
parameters = {'n_estimators':[int(x) for x in np.linspace(100,1000,10)]}
rf_regressor= GridSearchCV(rf, parameters, scoring='neg_mean_squared_error')
rf_regressor.fit(X_train, y_train.ravel())
print(rf_regressor.best_params_)
print(-rf_regressor.best_score_)
# Out:
# {'n_estimators': 100}
# 43.410261999999996

# %%
rf_reg= RandomForestRegressor(n_estimators=100)
rf_reg.fit(X_train, y_train.ravel())
rf_reg_pred = rf_reg.predict(X_test)
print('R2_score:',r2_score(y_test,pred))
print('mse:',mean_squared_error(y_test,pred))
print('mae:',mean_absolute_error(y_test,pred))
print('rmse:',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2_score: 0.692394090062741
# mse: 41.73396100536526
# mae: 5.603772629212078
# rmse: 6.4601827377687435

# %%
rmse_compilation= {
    'model':['Linear Regression', 'SGD','Lasso Regressor','Ridge Regressor','RandomForest'],
    'RMSE':[5.548273450820231, 5.394508115342373, 4.261436879917484, 6.4601827377687435, 6.4601827377687435]
}
rmse_df=pd.DataFrame(data=rmse_compilation)
rmse_df.sort_values(by=['RMSE'], ascending=True)
# Out:
#                model      RMSE
# 2    Lasso Regressor  4.261437
# 1                SGD  5.394508
# 0  Linear Regression  5.548273
# 3    Ridge Regressor  6.460183
# 4       RandomForest  6.460183

# %% [markdown]
# from this we can conclude Lasso regressor is best model

# %%
parameter = {'alpha':[0.01,0.1,1.0,10.26],
            'selection':['cyclic','random'],
            'max_iter':[2,4,6,8,10],
            'tol':[100,1000],
            'fit_intercept':['bool']}

# %%
GVC=GridSearchCV(Lasso(),parameter,cv=5)

# %%
GVC.fit(X_train,y_train)
GridSearchCV(cv=5, estimator=Lasso(),
             param_grid={'alpha': [0.01, 0.1, 1.0, 10.26],
                         'fit_intercept': ['bool'],
                         'max_iter': [2, 4, 6, 8, 10],
                         'selection': ['cyclic', 'random'],
                         'tol': [100, 1000]})
GVC.best_params_
# Out:
# {'alpha': 1.0,
#  'fit_intercept': 'bool',
#  'max_iter': 10,
#  'selection': 'random',
#  'tol': 100}

# %%
Final_mod=Lasso(alpha=1.0, fit_intercept="bool", max_iter=10, selection="random", tol=100)
Final_mod.fit(X_train,y_train)
pred=Final_mod.predict(X_test)
print('R2_Score:',r2_score(y_test,pred)*100)
print('mean_squared_error:',mean_squared_error(y_test,pred))
print('mean_absolute_error:',mean_absolute_error(y_test,pred))
print("RMSE value:",np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2_Score: 85.77442003991746
# mean_squared_error: 19.300337872373227
# mean_absolute_error: 3.660913039890744
# RMSE value: 4.393214981351724

# %% [markdown]
# After tuning got 85.77% accuracy which is good.

# %% [markdown]
# ## Saving the model

# %%
import pickle

# %%
filename= 'Base Ball Case Study'
pickle.dump(ls, open(filename,'wb'))
